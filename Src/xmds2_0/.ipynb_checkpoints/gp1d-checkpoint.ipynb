# %%
#%reset
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt 

import shlex, subprocess, time
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# !ls -lrt
# Out:
# total 12672
# -rw------- 1 subasi subasi     3489 Sep 30 14:41 gp1d.xmds
# -rw------- 1 subasi subasi    86326 Sep 30 14:41 xgp1d.cc
# -rwxr-xr-x 1 subasi subasi 12613760 Sep 30 14:41 xgp1d
# -rw------- 1 subasi subasi     4444 Sep 30 14:41 gp1d.xsil
# -rw------- 1 subasi subasi   177552 Sep 30 14:41 gp1d.h5
# -rw-r--r-- 1 subasi subasi     1033 Sep 30 14:47 gp1d.m
# -rw------- 1 subasi subasi     1120 Sep 30 14:49 gp1d.py
# -rw------- 1 subasi subasi    67056 Sep 30 15:00 gp1d.ipynb

# %%
start_time = time.time()
cmdline  = 'xmds2 gp1d.xmds'
args = shlex.split(cmdline)
p=subprocess.Popen(args)
p.wait()
# !ls -lrt
# Out:
# total 12792
# -rw------- 1 subasi subasi     3489 Sep 30 14:41 gp1d.xmds
# -rwxr-xr-x 1 subasi subasi 12613760 Sep 30 14:41 xgp1d
# -rw------- 1 subasi subasi     4444 Sep 30 14:41 gp1d.xsil
# -rw------- 1 subasi subasi   177552 Sep 30 14:41 gp1d.h5
# -rw-r--r-- 1 subasi subasi     1033 Sep 30 14:47 gp1d.m
# -rw------- 1 subasi subasi     1120 Sep 30 14:49 gp1d.py
# -rw------- 1 subasi subasi    67056 Sep 30 15:00 gp1d.ipynb
# -rw------- 1 subasi subasi    86326 Sep 30 16:43 xgp1d.cc
# -rw-r--r-- 1 subasi subasi   122712 Sep 30 16:43 xgp1d.cc.1.o

# %%
cmdline  = './xgp1d'
args = shlex.split(cmdline)
p=subprocess.Popen(args)
p.wait()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 1.78892922401 seconds ---

# %%
start_time = time.time()
cmdline  = 'xsil2graphics2 -p gp1d.xsil'
args = shlex.split(cmdline)
p=subprocess.Popen(args)
p.wait()
# !ls
# Out:
# gp1d.h5  gp1d.ipynb  gp1d.m  gp1d.py  gp1d.xmds  gp1d.xsil  xgp1d  xgp1d.cc

# %%
# %run gp1d.py
np.size(v1_3)
# Out:
# 1024

# %%
np.shape(dens_1), np.shape(x_1), np.shape(phiI_1),np.shape(phiR_1), np.shape(norm_2), np.shape(v1_3), np.shape(e1_2)

np.savetxt('pot_en.dat',np.concatenate((v1_3, e1_2[-2:-1])).reshape(1,np.size(v1_3)+1))

# %%
fig, ax = plt.subplots(1,3,figsize=(18,6))

ax[0].plot(x_1,dens_1[-1,:],'b.-', x_1, v1_3[:]/100., 'k-')

ax[1].plot(x_1,phiR_1[-1,:],'b.-')
ax[1].plot(x_1,phiI_1[-1,:],'g.-')

ax[2].plot(norm_2[:],'ro-', label='norm')

# %% [markdown]
# # http://cpc.cs.qub.ac.uk/summaries/AEDU_v1_0.html

# %%
pwd
# Out:
# u'/home/subasi/MEGA/ders/fiz421e/huseyin_senyasa/APPL/Src/xmds2'

# %%
start_time = time.time()
cmdline  = 'gfortran imagtime1d.F -o ximagtime1d'
args = shlex.split(cmdline)
p=subprocess.Popen(args,cwd=r'../adeu_v1_imagtime1d')
p.wait()

# %%
cmdline  = './ximagtime1d'
args = shlex.split(cmdline)
p=subprocess.Popen(args,cwd=r'../adeu_v1_imagtime1d')
p.wait()
# !ls -lrt
# Out:
# total 12792
# -rw------- 1 subasi subasi     3489 Sep 30 14:41 gp1d.xmds
# -rwxr-xr-x 1 subasi subasi 12613760 Sep 30 14:41 xgp1d
# -rw------- 1 subasi subasi     4444 Sep 30 14:41 gp1d.xsil
# -rw------- 1 subasi subasi   177552 Sep 30 14:41 gp1d.h5
# -rw-r--r-- 1 subasi subasi     1033 Sep 30 14:47 gp1d.m
# -rw------- 1 subasi subasi    86326 Sep 30 16:43 xgp1d.cc
# -rw-r--r-- 1 subasi subasi   122712 Sep 30 16:43 xgp1d.cc.1.o
# -rw------- 1 subasi subasi     1120 Sep 30 16:43 gp1d.py
# -rw------- 1 subasi subasi    69398 Sep 30 16:45 gp1d.ipynb

# %%
f1=np.loadtxt('../adeu_v1_imagtime1d/fort.1')
f2=np.loadtxt('../adeu_v1_imagtime1d/fort.2')
f3=np.loadtxt('../adeu_v1_imagtime1d/fort.3')

f1[:,0]
# Out:
# array([-10.    ,  -9.9975,  -9.995 , ...,   9.995 ,   9.9975,  10.    ])

# %%
fig, ax = plt.subplots(1,3,figsize=(18,6))

ax[0].plot(f1[:,0]*2,f1[:,1]/4,'b.-', label="initial")

ax[1].plot(f2[:,0],f2[:,1],'b.-', label="test")

ax[2].plot(f3[:,0],f3[:,1],'b.-',  x_1, phiR_1[-1,:],'r.-', label="final")
# Out:
# [<matplotlib.lines.Line2D at 0x7fc5f463b290>,
#  <matplotlib.lines.Line2D at 0x7fc5f4770050>]
